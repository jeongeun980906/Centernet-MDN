# %%
import torch
import cv2
import os
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

from model.MDN_hourglass import MDN_hourglass
from core.mixture_loss import mace_loss,_gather,mln_uncertainties
import seaborn as sns
from utils.utils import count_parameters
from utils.voc import VOC_NAMES,PascalVOC_eval
import random
from utils.image import transform_preds
from utils.post_process import ctdet_decode

# %%
device='cuda'
VOC_COLORS = sns.color_palette('hls', len(VOC_NAMES))

# %%
model = MDN_hourglass(n=5, nstack=2, dims=[256, 256, 384, 384, 384, 512], 
                                    modules=[2, 2, 2, 2, 2, 4],num_classes=20).to(device)
path = './ckpt/mdn/{}/{}.pt'.format(2,19)
state_dict=torch.load(path)
model.load_state_dict(state_dict)
count_parameters(model)
# Out:
# Total num of param = 193.716288 M

# %%
dataset = PascalVOC_eval(root='/data/private/voc',split='val')

rnd_idx = random.choice([i for i in range(dataset.__len__())])
demo_data = dataset.__getitem__(rnd_idx)
img_path = dataset.images[rnd_idx]
img_path =  os.path.join(dataset.img_dir, dataset.coco.loadImgs(ids=[img_path])[0]['file_name'])
demo_image = cv2.imread(img_path) #[BGR]
demo_image = cv2.cvtColor(demo_image, cv2.COLOR_BGR2RGB)
print(rnd_idx)
# Out:
# ==> initializing pascal test2007 data.
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# Loaded 4952 val samples
# 3342

# %%
plt.axis('off')
plt.imshow(demo_image)
plt.show()

# %%
inputs = demo_data[1][1]['image']
inputs = torch.FloatTensor(inputs)
output = model(inputs.to(device))[-1]
pi = output[0]['pi']
mu = output[0]['mu']
sigma = output[0]['sigma']
output[0] = _gather(pi,mu,sigma)['mu_prime']
dets = ctdet_decode(*output)
dets = dets.detach().cpu().numpy().reshape(1, -1, dets.shape[2])[0]

top_preds = {}
dets[:, :2] = transform_preds(dets[:, 0:2],
                            demo_data[1][1]['center'],
                            demo_data[1][1]['scale'],
                            (demo_data[1][1]['fmap_w'], demo_data[1][1]['fmap_h']))
dets[:, 2:4] = transform_preds(dets[:, 2:4],
                            demo_data[1][1]['center'],
                            demo_data[1][1]['scale'],
                            (demo_data[1][1]['fmap_w'], demo_data[1][1]['fmap_h']))
cls = dets[:, -1]
for j in range(dataset.num_classes):
    inds = (cls == j)
    top_preds[j + 1] = dets[inds, :5].astype(np.float32)
    top_preds[j + 1][:, :4] /= 1
detections = [top_preds]

# %%
bbox_and_scores = {}
for j in range(1, 21):
    bbox_and_scores[j] = np.concatenate([d[j] for d in detections], axis=0)
scores = np.hstack([bbox_and_scores[j][:, 4] for j in range(1, 21)])

if len(scores) > 100:
    kth = len(scores) - 100
    thresh = np.partition(scores, kth)[kth]
    for j in range(1, 21):
        keep_inds = (bbox_and_scores[j][:, 4] >= thresh)
        bbox_and_scores[j] = bbox_and_scores[j][keep_inds]

# %%
fig = plt.figure(0)
colors = VOC_COLORS
names = VOC_NAMES
plt.imshow(demo_image)
for lab in bbox_and_scores:
    for boxes in bbox_and_scores[lab]:
        x1, y1, x2, y2, score = boxes
    if score > 0.03:
        plt.gca().add_patch(Rectangle((x1, y1), x2 - x1, y2 - y1,
                                    linewidth=2, edgecolor=colors[lab], facecolor='none'))
        plt.text(x1 + 3, y1 + 3, names[lab] + '%.2f' % score,
                bbox=dict(facecolor=colors[lab], alpha=0.5), fontsize=7, color='k')

fig.patch.set_visible(False)
plt.axis('off')
#plt.savefig('demo_results.png', dpi=300, transparent=True)
plt.show()

# %% [markdown]
# ## Plot Heatmap

# %%
heatmap = torch.sigmoid(output[0])
m = torch.nn.Upsample(scale_factor=(4,4), mode='nearest')
heatmap = m(heatmap).squeeze(0)
heatmap = torch.sum(heatmap,dim=0)/20
heatmap = heatmap.detach().cpu().numpy()
heatmap = cv2.resize(heatmap, (demo_image.shape[1],demo_image.shape[0]))

# %%
plt.title("Center Heatmap")
plt.axis('off')
plt.imshow(demo_image)
plt.imshow(heatmap,alpha=0.5,cmap='jet')
plt.show()

# %% [markdown]
# ## Plot Uncertainty

# %%
unct_out = mln_uncertainties(pi,mu,sigma)
epis = unct_out['epis'].unsqueeze(0)
alea = unct_out['alea'].unsqueeze(0)
epis = m(epis).squeeze(0).squeeze(0)
alea = m(alea).squeeze(0).squeeze(0)
epis = epis.detach().cpu().numpy()
epis = cv2.resize(epis, (demo_image.shape[1],demo_image.shape[0]))
alea = alea.detach().cpu().numpy()
alea = cv2.resize(alea, (demo_image.shape[1],demo_image.shape[0]))

# %%
plt.title("Epistemic Uncertainty Heatmap")
plt.axis("off")
plt.imshow(demo_image)
plt.imshow(epis,alpha=0.4,cmap='jet')
plt.show()

# %%
plt.title("Aleatoric Uncertainty Heatmap")
plt.axis("off")
plt.imshow(demo_image)
plt.imshow(alea,alpha=0.5,cmap='jet')
plt.show()

# %% [markdown]
# ### Plot Total

# %%
plt.figure(0)

plt.subplot(1,4,1)
plt.title("Demo Image", fontsize=5)
plt.axis('off')
plt.imshow(demo_image)

plt.subplot(1,4,2)
plt.title("Center Heatmap",fontsize=5)
plt.axis('off')
plt.imshow(demo_image)
plt.imshow(heatmap,alpha=0.4,cmap='jet')

plt.subplot(1,4,3)
plt.title("Epistemic Uncertainty Heatmap",fontsize=5)
plt.axis("off")
plt.imshow(demo_image)
plt.imshow(epis,alpha=0.4,cmap='jet')
plt.subplot(1,4,4)
plt.title("Aleatoric Uncertainty Heatmap",fontsize=5)
plt.axis("off")
plt.imshow(demo_image)
plt.imshow(alea,alpha=0.4,cmap='jet')
plt.show()

# %%
mixture_center = torch.sum(mu,dim=2)/20
sorted_pi,pi_index = torch.sort(pi,dim=2) 
mixture_center = torch.gather(mixture_center,dim=-1,index = pi_index)
mixture_center = m(mixture_center).squeeze(0)
print(mixture_center.size())
for i in range(mixture_center.size(0)):
    img = mixture_center[i].cpu().detach().numpy()
    plt.subplot(1,10,i+1)
    plt.imshow(demo_image)
    plt.imshow(img,alpha=0.5,cmap='jet')
# Out:
# torch.Size([10, 384, 384])
